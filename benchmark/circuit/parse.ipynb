# %%
from qiskit import QuantumCircuit
from qiskit.circuit import library

# %%
qc = QuantumCircuit.from_qasm_file('rd32-v0_66.qasm')
qc.draw(output='mpl')

# %%
qc = QuantumCircuit.from_qasm_file('rd32-v1_68.qasm')
qc.draw(output='mpl')
