# %%
import sys
sys.path.append('../')
import numpy as np

# %%
from su4compiler import *
import qiskit
import cirq

# %% [markdown]
# To verify that benchmark programs in [tof/](tof/) are gate sequence comprised of only Toffoli gates.

# %% [markdown]
# **`tof_3.qasm`**

# %%
circ = Circuit.from_qasm(fname='./tof/tof_3.qasm')
u1 = circ.unitary()
circ.to_qiskit().draw('mpl',fold=40)

# %%
# qc = qiskit.QuantumCircuit(3)
# qc.ccx(0,1,2)
# qc.decompose().draw('mpl',fold=40)

# %%
circ = decompose.ccx_decompose(gate.X.on(4, [0,1])) + decompose.ccx_decompose(gate.X.on(3, [4,2])) + decompose.ccx_decompose(gate.X.on(4, [0,1]))
u2 = circ.unitary()
circ.to_qiskit().draw('mpl',fold=40)

# %%
cirq.testing.assert_allclose_up_to_global_phase(
    u1, u2, atol=1e-5
)

# %% [markdown]
# **`tof_4.qasm`**

# %%
circ = Circuit.from_qasm(fname='./tof/tof_4.qasm')
circ.to_qiskit().draw('mpl',fold=40)
