# %%
import sys
sys.path.append('../')

# %%
from su4compiler import gate, circuit
from qiskit import QuantumCircuit
from qiskit.transpiler import PassManager
from qiskit.transpiler import passes
from cirq.contrib.svg import SVGCircuit

# %%
# circ = circuit.Circuit.from_qasm(fname='./pf/pf2_10.qasm')
# circ = circuit.Circuit.from_qasm(fname='./uccsd/H2_cmplt_P_631g.qasm')
# circ = circuit.Circuit.from_qasm(fname='./vqe_uccsd/vqe_uccsd_4.qasm')
circ = circuit.Circuit.from_qasm(fname='./qaoa/qaoa_8.qasm')
# circ = circuit.Circuit.from_qasm(fname='./ising/ising_model_10.qasm')
# circ = circuit.Circuit.from_qasm(fname='./qft/qft_8.qasm')
# circ = circuit.Circuit.from_qasm(fname='./grover/grover_5_0.qasm')
# circ = circuit.Circuit.from_qasm(fname='./sym/sym9_146.qasm')
# circ = circuit.Circuit.from_qasm(fname='./ham/ham7_104.qasm')
# circ = circuit.Circuit.from_qasm(fname='./bit_adder/rd73_140.qasm')
# circ = circuit.Circuit.from_qasm(fname='./mult/gf2^4_mult.qasm')
# circ = circuit.Circuit.from_qasm(fname='./modulo/4mod5-v1_23.qasm')
# circ = circuit.Circuit.from_qasm(fname='./comparator/4gt12-v0_87.qasm')
# circ = circuit.Circuit.from_qasm(fname='./alu/alu-v3_34.qasm')


# circ = circuit.Circuit(circ[:300])
print(circ.to_cirq())
# Out:
#                                                                              ┌──┐                 ┌──┐   ┌───┐                ┌───┐                                                                                                                                                                                                                                                                                                             ┌──┐                 ┌──┐   ┌───┐                 ┌───┐                                                                                                                                                                                                                                                                                                              ┌──┐                ┌──┐   ┌───┐                 ┌───┐                                                                                                                                                           
# ...

# %%
circ.to_qiskit().draw(output='mpl', style='iqp', fold=80, filename='../output.png')

# %%
SVGCircuit(circ.to_cirq())

# %%
circ = circuit.Circuit.from_qasm(fname='./qaoa/qaoa_8.qasm')
print(circ.to_cirq())
# Out:
#                                                                              ┌──┐                 ┌──┐   ┌───┐                ┌───┐                                                                                                                                                                                                                                                                                                             ┌──┐                 ┌──┐   ┌───┐                 ┌───┐                                                                                                                                                                                                                                                                                                              ┌──┐                ┌──┐   ┌───┐                 ┌───┐                                                                                                                                                           
# ...

# %%
circ = circuit.Circuit.from_qasm(fname='./mcx/tof_3.qasm')
print(circ.to_cirq())
# Out:
#                                                                                                            ┌──┐          ┌──┐
# q_0: ──────────────────────────@──────────────────@───@───T──────@─────────────────────────────────────────────────────────────────────────────────────@──────────────────@───@───T──────@───────
#                                │                  │   │          │                                                                                     │                  │   │          │
# q_1: ───────────────@──────────┼───────@───T──────┼───X───T^-1───X──────────────────────────────────────────────────────────────────────────@──────────┼───────@───T──────┼───X───T^-1───X───────
#                     │          │       │          │                                                                                         │          │       │          │
# ...

# %%
# MAJ
qc = QuantumCircuit(3)
qc.cx(2, 1)
qc.cx(2, 0)
qc.ccx(0, 1, 2)
qc.draw('mpl', style='clifford')

# %%
# UMA
qc = QuantumCircuit(3)
qc.ccx(0, 1, 2)
qc.cx(2, 0)
qc.cx(0, 1)
qc.decompose().draw('mpl', style='clifford')
